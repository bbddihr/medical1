# %% [markdown]
# Decision Tree

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
#복잡한 샘플 데이터 생성
x_train, y_train=make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)

#test_data
x_test = np.array([[0,0]])

# %%
#DC tree훈련
tree_model =DecisionTreeClassifier(random_state=42)
tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
predicted_label=tree_model.predict(x_test)

# %%
#criterion: "gini","entropy","log_loss", default는 gini
#max_depth 가지치기의 기준 
#min_samples_split
#min_samples_leap

#기본값으로 돌려본다.> 하이퍼파라미터튜닝.> thresold 인계치
#pruning 가지치기

# %%
# 시각화
plt.figure()
plt.contour(scatter_vis(x_train,x_test,y_train,tree_model),figsize=(12,8))
plt.contour(xx,yy,Z, alpha=0.3, cmap=plt.cm.coolwarm)

plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f"DC Tree Classification\nPredicted label for test point: {predicted_label[0]}")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 시각화
#       2 plt.figure()
# ----> 3 plt.contour(scatter_vis(x_train,x_test,y_train,tree_model),figsize=(12,8))
#       4 plt.contour(xx,yy,Z, alpha=0.3, cmap=plt.cm.coolwarm)
#       6 plt.legend()
#
# NameError: name 'scatter_vis' is not defined

# %%
# 트리모델 시각화
# 시각화
plt.figure(figsize=(10, 8))
for i, point in enumerate(x_train):
    plt.scatter(point[0], point[1], c='r' if y_train[i] == 0 else 'b', marker='o',
                label='Class 0' if y_train[i] == 0 and i == 0 else ('Class 1' if y_train[i] == 1 and i == 1 else ''))
plt.scatter(x_test[0, 0], x_test[0, 1], c='g', marker='x', s=100, label='Test Point')
x_min, x_max = x_train[:, 0].min()-1, x_train[:, 0].max()+1
y_min, y_max = x_train[:, 1].min()-1, x_train[:, 1].max()+1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
Z = tree_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f"DC Tree Classification\nPredicted label for test point: {predicted_label[0]}")
plt.grid(True)
plt.show()

# %%
#의사결정나무 구조 시각화
plt.figure(figsize=(20,10))
plot_tree(tree_model, filled=True,feature_names=['X','Y'],class_names=['Class 0','Class 1'])
# Out:
# [Text(0.45588235294117646, 0.9545454545454546, 'X <= -0.0\ngini = 0.5\nsamples = 200\nvalue = [100, 100]\nclass = Class 0'),
#  Text(0.22058823529411764, 0.8636363636363636, 'Y <= 0.569\ngini = 0.209\nsamples = 93\nvalue = [82, 11]\nclass = Class 0'),
#  Text(0.3382352941176471, 0.9090909090909092, 'True  '),
#  Text(0.11764705882352941, 0.7727272727272727, 'Y <= 0.28\ngini = 0.369\nsamples = 41\nvalue = [31, 10]\nclass = Class 0'),
#  Text(0.058823529411764705, 0.6818181818181818, 'X <= -2.591\ngini = 0.231\nsamples = 30\nvalue = [26, 4]\nclass = Class 0'),
#  Text(0.029411764705882353, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.08823529411764706, 0.5909090909090909, 'X <= -1.196\ngini = 0.185\nsamples = 29\nvalue = [26, 3]\nclass = Class 0'),
#  Text(0.058823529411764705, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Class 0'),
#  Text(0.11764705882352941, 0.5, 'X <= -1.137\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = Class 0'),
#  Text(0.08823529411764706, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.14705882352941177, 0.4090909090909091, 'X <= -0.651\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = Class 0'),
#  Text(0.11764705882352941, 0.3181818181818182, 'Y <= -0.328\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Class 0'),
#  Text(0.08823529411764706, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Class 0'),
#  Text(0.14705882352941177, 0.22727272727272727, 'Y <= 0.105\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Class 1'),
#  Text(0.11764705882352941, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Class 1'),
#  Text(0.17647058823529413, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.17647058823529413, 0.3181818181818182, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Class 0'),
#  Text(0.17647058823529413, 0.6818181818181818, 'X <= -1.55\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = Class 1'),
#  Text(0.14705882352941177, 0.5909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Class 0'),
#  Text(0.20588235294117646, 0.5909090909090909, 'Y <= 0.437\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Class 1'),
#  Text(0.17647058823529413, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Class 1'),
#  Text(0.23529411764705882, 0.5, 'Y <= 0.539\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Class 0'),
#  Text(0.20588235294117646, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Class 0'),
#  Text(0.2647058823529412, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.3235294117647059, 0.7727272727272727, 'Y <= 0.983\ngini = 0.038\nsamples = 52\nvalue = [51, 1]\nclass = Class 0'),
#  Text(0.29411764705882354, 0.6818181818181818, 'Y <= 0.896\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Class 0'),
#  Text(0.2647058823529412, 0.5909090909090909, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Class 0'),
#  Text(0.3235294117647059, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.35294117647058826, 0.6818181818181818, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]\nclass = Class 0'),
#  Text(0.6911764705882353, 0.8636363636363636, 'X <= 0.793\ngini = 0.28\nsamples = 107\nvalue = [18, 89]\nclass = Class 1'),
#  Text(0.5735294117647058, 0.9090909090909092, '  False'),
#  Text(0.5, 0.7727272727272727, 'Y <= 0.03\ngini = 0.472\nsamples = 42\nvalue = [16, 26]\nclass = Class 1'),
#  Text(0.4117647058823529, 0.6818181818181818, 'X <= 0.128\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Class 0'),
#  Text(0.38235294117647056, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.4411764705882353, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Class 0'),
#  Text(0.5882352941176471, 0.6818181818181818, 'Y <= 1.699\ngini = 0.438\nsamples = 37\nvalue = [12, 25]\nclass = Class 1'),
#  Text(0.5, 0.5909090909090909, 'X <= 0.476\ngini = 0.358\nsamples = 30\nvalue = [7, 23]\nclass = Class 1'),
#  Text(0.47058823529411764, 0.5, 'Y <= 0.702\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = Class 1'),
#  Text(0.38235294117647056, 0.4090909090909091, 'Y <= 0.167\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Class 0'),
#  Text(0.35294117647058826, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.4117647058823529, 0.3181818181818182, 'X <= 0.208\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Class 0'),
#  Text(0.38235294117647056, 0.22727272727272727, 'X <= 0.051\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Class 1'),
#  Text(0.35294117647058826, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.4117647058823529, 0.13636363636363635, 'X <= 0.136\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Class 0'),
#  Text(0.38235294117647056, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.4411764705882353, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1'),
#  Text(0.4411764705882353, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Class 0'),
#  Text(0.5588235294117647, 0.4090909090909091, 'X <= 0.429\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Class 1'),
#  Text(0.5294117647058824, 0.3181818181818182, 'X <= 0.342\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Class 1'),
#  Text(0.5, 0.22727272727272727, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Class 1'),
#  Text(0.5588235294117647, 0.22727272727272727, 'Y <= 1.094\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Class 1'),
#  Text(0.5294117647058824, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.5882352941176471, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Class 1'),
#  Text(0.5882352941176471, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.5294117647058824, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Class 1'),
#  Text(0.6764705882352942, 0.5909090909090909, 'Y <= 1.946\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Class 0'),
#  Text(0.6470588235294118, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Class 0'),
#  Text(0.7058823529411765, 0.5, 'Y <= 2.51\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Class 0'),
#  Text(0.6764705882352942, 0.4090909090909091, 'X <= 0.683\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Class 1'),
#  Text(0.6470588235294118, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Class 1'),
#  Text(0.7058823529411765, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.7352941176470589, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Class 0'),
#  Text(0.8823529411764706, 0.7727272727272727, 'Y <= 3.148\ngini = 0.06\nsamples = 65\nvalue = [2, 63]\nclass = Class 1'),
#  Text(0.8235294117647058, 0.6818181818181818, 'Y <= -0.007\ngini = 0.031\nsamples = 63\nvalue = [1, 62]\nclass = Class 1'),
#  Text(0.7941176470588235, 0.5909090909090909, 'Y <= -0.09\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Class 1'),
#  Text(0.7647058823529411, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Class 1'),
#  Text(0.8235294117647058, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.8529411764705882, 0.5909090909090909, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]\nclass = Class 1'),
#  Text(0.9411764705882353, 0.6818181818181818, 'X <= 2.261\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Class 0'),
#  Text(0.9117647058823529, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Class 0'),
#  Text(0.9705882352941176, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Class 1')]

# %%
#decision tree이용
#병변 크기와 두께 
#유방암 wsc data 가지고 많이 씀.
