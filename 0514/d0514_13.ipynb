# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family']='Malgun Gothic'  #한글설정
matplotlib.rcParams['font.size']= 10  #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values=[30,25,20,13,10,2]  #100
# values=[10,5,10,7,6,2]
titles= ['Python','Java','Javascript','c#','c','ETC']
explode =[0.1]*6
colors=['#f05d43','#f2d58d','#b8e053','#53e0b8','#53ade0','#ba93f5']
wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':2}
#시작위치: startangle
#데이터 표시: autopct
#회전방향 : counterclock=False 시계방향
#파이 사이 간격: explode
plt.pie(values,titles=titles,autopct='%.1f%%',explode=explode, startangle=90,counterclock=False)
plt.title('전체 언어별 선호도')
plt.legend(loc=(1.1,0.3))
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       6 wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':2}
#       7 #시작위치: startangle
#       8 #데이터 표시: autopct
#       9 #회전방향 : counterclock=False 시계방향
#      10 #파이 사이 간격: explode
# ---> 11 plt.pie(values,titles=titles,autopct='%.1f%%',explode=explode, startangle=90,counterclock=False)
#      12 plt.title('전체 언어별 선호도')
#      13 plt.legend(loc=(1.1,0.3))
#
# TypeError: pie() got an unexpected keyword argument 'titles'

# %%
plt.pie(values,labels=labels,autopct='%1.f%%',startangle=90,
        colors=colors,counterclock=False, wedgeprops=wedgeprops)
plt.show()
