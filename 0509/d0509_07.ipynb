# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90    5  100  95  85      python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  구로고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          C#

# %%
#pandas:데이터컬럼 전체적으로 수정하는 형태 
df['학교']='디지털고'
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  디지털고  197   90    5  100  95  85      python
# 2번    강태원  디지털고  184   40   35   50  55  25        Java
# 3번    강호림  디지털고  168   80   75   70  80  75  Javascript
# 4번    김수찬  디지털고  187   40   60   70  75  80         NaN
# 5번    김재욱  디지털고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
data={
    "name":['홍길동','유관순','이순신','김구','강감찬'],
    "phone":"010-1111-1111",
    "gender":"male"
}
data['name']='홍길자'
data
# Out:
# {'name': '홍길자', 'phone': '010-1111-1111', 'gender': 'male'}

# %%
for d in data['name']:
    d='홍길자'
    
data['name']
# Out:
# '홍길자'

# %%
df['학교'].replace({'구로고':'디지털고'},inplace=True)
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  디지털고  197   90    5  100  95  85      python
# 2번    강태원  디지털고  184   40   35   50  55  25        Java
# 3번    강호림  디지털고  168   80   75   70  80  75  Javascript
# 4번    김수찬  디지털고  187   40   60   70  75  80         NaN
# 5번    김재욱  디지털고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %% [markdown]
# 데이터수정:columns수정

# %%
#학교 컬럼 모두 디지털 

#학교컬럼중에 구로고를 디지털고로 변경
df['학교'].replace({'구로고'='디지털고'})

# %%
##SW 특기컬럼에서 java가 포함되어있는 열을 출력 
filt=df['SW특기'].str.contains('Java',na=False)
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40  35  50  55  25        Java
# 3번    강호림  구로고  168  80  75  70  80  75  Javascript

# %%
df.fillna("미선택",inplace=True)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90    5  100  95  85      python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         미선택
# 5번    김재욱  구로고  188   15   20   10  35  10         미선택
# 6번    박동현  구로고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          C#

# %%
#문구를 수정해서 출력
df['학교'] = df["학교"]+'등학교'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고등학교  197   90    5  100  95  85      python
# 2번    강태원  구로고등학교  184   40   35   50  55  25        Java
# 3번    강호림  구로고등학교  168   80   75   70  80  75  Javascript
# 4번    김수찬  구로고등학교  187   40   60   70  75  80         미선택
# 5번    김재욱  구로고등학교  188   15   20   10  35  10         미선택
# 6번    박동현  구로고등학교  202   80  100   95  85  80           C
# 7번    박혜정  단지고등학교  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고등학교  190  100   85   90  95  95          C#

# %%
#과학점수를 +5점을 더해서 출력하시오.
df['과학'] = df['과학']+5
df

#국어점수를 +10점
df['국어']=df['국어']+10
df
# Out:
#        이름      학교    키   국어   영어   수학   과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고등학교  197  100    5  100  105  85      python
# 2번    강태원  구로고등학교  184   50   35   50   65  25        Java
# 3번    강호림  구로고등학교  168   90   75   70   90  75  Javascript
# 4번    김수찬  구로고등학교  187   50   60   70   85  80         미선택
# 5번    김재욱  구로고등학교  188   25   20   10   45  10         미선택
# 6번    박동현  구로고등학교  202   90  100   95   95  80           C
# 7번    박혜정  단지고등학교  188   65   65   45   50  35      PYTHON
# 8번    승근열  단지고등학교  190  110   85   90  105  95          C#
