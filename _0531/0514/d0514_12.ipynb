# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family']='Malgun Gothic'  #한글설정
matplotlib.rcParams['font.size']= 10  #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df=pd.read_csv('../z20_data/drinks.csv',index_col='country')
df.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0              0.0            0.0
# Albania               89.0            132.0           54.0
# Algeria               25.0              0.0           14.0
# Andorra              245.0            138.0          312.0
# Angola               217.0             57.0           45.0
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
df.shape
# Out:
# (194, 5)

# %%
#대륙별 개수를 출력하시오. AS,Eu,AF 
#가장 많은 수으로 정렬
#가장 많은 개수는 
df['continent'].value_counts()
# Out:
# continent
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, Afghanistan to 22
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   beer_servings                 193 non-null    float64
#  1   spirit_servings               193 non-null    float64
#  2   wine_servings                 193 non-null    float64
#  3   total_litres_of_pure_alcohol  193 non-null    float64
#  4   continent                     170 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 9.1+ KB

# %%
df.fillna('OT',inplace=True)
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27480\1570924296.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'OT' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('OT',inplace=True)

# %%
labels=df['continent'].value_counts().index
values=df['continent'].value_counts().values
explode=[0.5,0,0,0,0,0]
plt.pie(values,labels=labels,autopct='%.2f%%', startangle=90,explode=explode,counterclock=False)
plt.title('대륙별 술소비')
plt.legend(loc=(1.1,0.3))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# values=[30,25,20,13,10,2]  #100
# # values=[10,5,10,7,6,2]
# labels= ['Python','Java','Javascript','c#','c','ETC']
explode =[0.1]*6
colors=['#f05d43','#f2d58d','#b8e053','#53e0b8','#53ade0','#ba93f5']
wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':2}


# values:값
# labels: 표시(글자)
# autopct:파이내글자표시 및 퍼센트표시
# pctdistance:파이내 글자 표시
# startangle:원형이 시작하는 위치
# colors:그래프색상
# counterclock:그래프 내 데이터 배치-시계방향,반시계방향
# wedgeprops:도넛형태, 그래프 테두리 색상


plt.pie(values,labels=labels,autopct='%1.f%%',startangle=90,
        colors=colors,counterclock=False, wedgeprops=wedgeprops,
        pctdistance=0.7)
plt.legend(loc=(1.0,0.8))
plt.show()
