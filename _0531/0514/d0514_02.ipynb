# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family']='Malgun Gothic'  #한글설정
matplotlib.rcParams['font.size']= 15   #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df=pd.read_excel('../z20_data/score1.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교  학년    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197   90   85  100  95  85      Python
# 2번    강태원  구로고   3  184   40   35   50  55  25        Java
# 3번    강호림  구로고   2  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고   1  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고   1  188   15   20   10  35  10         NaN
# 6번    박동현  단지고   3  202   80  100   95  85  80           C
# 7번    박혜정  단지고   2  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고   2  190  100   85   90  95  95          c#

# %%
#이름과 국어 성적 가지고 선 그래프를 출력하시오.
x=df['이름']
y=df['국어']
plt.title('빅데이터반 성적그래프')
plt.plot(x,y,label='국어점수')
plt.bar(x,y,label='국어점수')
plt.legend(loc='upper center')

# %%
#chipotle.tsv 에서 주문 중 가장 많이 주문한 메뉴 10개를 꺽은선 그래프로 출력하시오.
import pandas as pd
df =pd.read_csv('../z20_data/chipotle.tsv',sep='\t')

df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#주문별 그룹
#quantity의 합구하기

#item_name별 주문한 개수의 합 출력
x=df['item_name']
y=df['quantity']

# %%
# ordercnt=df.groupby('item_name').count()
# ordercnt

#item_quantity=df.groupby('item_name')['quantity'].sum().sort_values(ascending=False)
item_quantity=df.groupby('item_name')['quantity'].sum().sort_values(ascending=False)
item_quantity
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
df.groupby('item_name')['quantity'].sum()[:5].sort_values(ascending=False)
df.groupby('item_name')['quantity'].sum()[:5].index
y2=df.groupby('item_name')['quantity'].sum()[:5].values

df['item_name'].value_counts()[:5]
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: count, dtype: int64

# %%
df['item_name'].value_counts()[:5]
df['item_name'].value_counts()[:5].index
y2=df['item_name'].value_counts()[:5].values

# %%
plt.figure(dpi=200)
plt.bar(x,y,label='주문수')
plt.plot(x,y,label='주문횟수')
plt.legend(loc='upper right')

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family']='Malgun Gothic'  #한글설정
matplotlib.rcParams['font.size']= 10  #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family']='Malgun Gothic'  #한글설정
matplotlib.rcParams['font.size']= 15   #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Text(0, 1, '이름')

# %%
x=['han','kim','hong']
y=[20,40,80]
y2=[40,20,80]
y3=[80,90,95]
#범례 이름지정
plt.plot(x,y,label='국어')
plt.plot(x,y2,label='영어')
plt.plot(x,y3,label='수학')
#범례 표시, 위치설정, ncol
# plt.legend(loc='upper left')
plt.title('막대그래프')
# x,y축의 설명문구,위치,색상
plt.xlabel('국어',loc='center',color='red')  #left,center,right
plt.ylabel('이름',loc='top',color='#ff9100')  #top,center,bottom
# plt.legend(loc='upper right')
# Out:
# Text(0, 1, '이름')
