# %%
import pandas as pd
df = pd.read_excel('202303_인구.xlsx')
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    ※ 매월 말일자 통계 현황 Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN        NaN    2023년01월         NaN        NaN        NaN
# 1             NaN        NaN           남         NaN        NaN        NaN
# 2          행정기관코드       행정기관       남 인구수     연령구간인구수       0~4세       5~9세
# 3      0000000000       전국    25,631,538  25,631,538    726,460  1,072,653
# 4      1100000000    서울특별시     4,567,739   4,567,739    116,614    161,429
# 5      2600000000    부산광역시     1,618,749   1,618,749     41,333     63,912
# 6      2700000000    대구광역시     1,162,217   1,162,217     31,269     49,000
# 7      2800000000    인천광역시     1,486,300   1,486,300     43,664     63,028
# 8      2900000000    광주광역시       706,724     706,724     21,506     32,852
# ...

# %%
df = pd.read_excel('202303_인구.xlsx',index_col='행정기관', skiprows=3,usecols='B,E,Y')
df.columns
df.head()
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세 100세 이상
# 행정기관
# 전국       726,460   1,307
# 서울특별시    116,614     276
# 부산광역시     41,333      72
# 대구광역시     31,269      25
# 인천광역시     43,664      82

# %%
w_df = pd.read_excel('202303_인구.xlsx',index_col='행정기관', skiprows=3,usecols='B,AB,AV')
w_df.head()
w_df.columns=df.columns
w_df.columns
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['0~4세', '100세 이상'], dtype='object')

# %%
import pandas as pd
df = pd.read_excel('202303_인구.xlsx',skiprows=3)
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         행정기관코드       행정기관       남 인구수     연령구간인구수     0~4세       5~9세  \
# 0            0       전국    25,631,538  25,631,538  726,460  1,072,653
# 1   1100000000    서울특별시     4,567,739   4,567,739  116,614    161,429
# 2   2600000000    부산광역시     1,618,749   1,618,749   41,333     63,912
# 3   2700000000    대구광역시     1,162,217   1,162,217   31,269     49,000
# 4   2800000000    인천광역시     1,486,300   1,486,300   43,664     63,028
# 5   2900000000    광주광역시       706,724     706,724   21,506     32,852
# 6   3000000000    대전광역시       721,037     721,037   21,241     31,032
# 7   3100000000    울산광역시       570,113     570,113   16,646     26,693
# 8   3600000000  세종특별자치시       191,769     191,769    9,524     13,733
# ...

# %%
# df[0:1]
# df.iloc[0]
# df.tail(2)
df.head()
df.columns
df
# df.iloc[0]  #0번째 rows데이터 가져오기
# df.iloc[0].str  #str타입으로 변경
# df[df.columns[-1]]
# df.iloc[0]=df.iloc[0].str.replace(",","").astype(int) #replace함수를 사용해서 ,를 제거  
# df.describe()
# Out:
#         행정기관코드       행정기관       남 인구수     연령구간인구수     0~4세       5~9세  \
# 0            0       전국    25,631,538  25,631,538  726,460  1,072,653
# 1   1100000000    서울특별시     4,567,739   4,567,739  116,614    161,429
# 2   2600000000    부산광역시     1,618,749   1,618,749   41,333     63,912
# 3   2700000000    대구광역시     1,162,217   1,162,217   31,269     49,000
# 4   2800000000    인천광역시     1,486,300   1,486,300   43,664     63,028
# 5   2900000000    광주광역시       706,724     706,724   21,506     32,852
# 6   3000000000    대전광역시       721,037     721,037   21,241     31,032
# 7   3100000000    울산광역시       570,113     570,113   16,646     26,693
# 8   3600000000  세종특별자치시       191,769     191,769    9,524     13,733
# 9   4100000000      경기도     6,842,226   6,842,226  216,863    313,113
# 10  4200000000      강원도       772,297     772,297   20,663     28,244
# 11  4300000000     충청북도       810,740     810,740   22,631     32,948
# ...

# %%
# Out:
#              행정기관코드
# count  1.800000e+01
# mean   3.466667e+09
# std    1.341641e+09
# min    0.000000e+00
# 25%    2.825000e+09
# 50%    3.850000e+09
# 75%    4.475000e+09
# max    5.000000e+09
